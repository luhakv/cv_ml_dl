# %% [markdown]
# ## Юнит 9. Профориентация в Data Science
# ### Skillfactory: DSPR-19
# ### Модуль 7. Трек «ML-инженер»

# %% [markdown]
# 1. О чём этот модуль?
#
# В предыдущем модуле вы познакомились со спецификой профессии ML-инженера. Пришло время внимательнее посмотреть на соответствующий трек второго года обучения, познакомиться со специалистом из сферы и прикоснуться к одной из интересных задач, с которой вы можете столкнуться в роли ML-инженера.
#
# ### ЧТО ВЫ УЗНАЕТЕ В ЭТОМ МОДУЛЕ?
#
# - узнаете, из каких тем состоит образовательная программа трека и какие результаты вы получите после их прохождения;
# - от опытного ML-инженера вы узнаете об особенностях его пути и получите советы по выбору направления в Data Science;
# - узнаете, с какими кейсами вы можете столкнуться в роли ML-инженера на примере опыта специалиста из сферы;
# - а также познакомитесь с рекомендательными системами и попробуете создать одну из них самостоятельно!
#
# ⭐️ Не забывайте уделять время рефлексии и оценке собственных ощущений. Нравится ли вам то, что вы узнали? Хотели бы вы заниматься этим? Представляете ли вы себя на месте специалиста-спикера?

# %% [markdown]
# → Программа трека ML-инженер отличается более глубоким погружением в уже изученные вами темы. Также вы разберёте бизнес-задачи и инженерные инструменты. Как и два других, этот трек фокусируется на практическом применении знаний и инструментов.
#
# ️Давайте посмотрим, что вас ждёт на треке ML-инженер!
#
# https://view.genial.ly/609bc328d22b940dcff6665a/interactive-content-dsprprogramma-treka-ml-engineer

# %% [markdown]
# ### 3. Глазами специалиста
#
# → Настало время познакомиться со специалистом в области ML.
#
# Знакомьтесь — Александр Кондрашкин. Сейчас он работает старшим аналитиком в КиноПоиске, и ему определённо есть о чём рассказать, начиная с должности разработчика и заканчивая собственным стартапом в области машинного обучения. Передаём ему слово!
#
# ⚡ Осторожно! Возможны инсайты :)

# %% [markdown]
# ### 4. Кейс из опыта ML-инженера
# → Как вы уже могли понять, ML-инжиниринг включает в себя довольно широкий спектр разнообразных задач, и потому специалист может столкнуться с большим количеством совершенно разных сложностей. Однако Александр Кондрашкин поделится с вами кейсами из практики и советами, которые будут важны для каждого будущего ML-инженера вне зависимости от специфики сферы.

# %% [markdown]
# ### Задание 4.1
# Как модель предсказания временных рядов может помочь взаимодействию с заказчиком в лице бизнеса? Выберите все верные варианты.
# Ответ:
# - A Через демонстрацию положительного влияния на метрику тех действий, которые были предприняты ранее
# - D Через использование её как альтернативы A/B-тестированию при невозможности его проведения
#
# ### Задание 4.2
# Как определить влияние использования модели на показатели прибыли в случае, если модель внедрена в один из семи сервисов, работающих по одной подписке?
# Ответ: Высчитывать соотношение прибыли по соотношению активности пользователя в сервисах

# %% [markdown]
# ### 5. Рекомендательные системы
#
# Привет! С вами снова Эмиль Магеррамов.
#
# Машинное обучение — сложная область. Но сложная не потому, что ей сложно обучиться, а потому, что во время обучения перед вами встаёт выбор: в какое из направлений пойти. Машинное обучение сейчас применяется в разных сферах: от финансов до нефтяной отрасли. При этом писать модели машинного обучения не так уж сложно, и мы сейчас в этом убедимся.
#
# Давайте напишем свою модель машинного обучения и сделаем её визуальный прототип!
#
# Для начала выберем, какую модель мы будем делать и для чего она нужна. Если вы много читаете, то знаете, как важны рекомендации. Особенно хорошо, если рекомендации основываются на том, что вам самим нравится.
#
# ✏️ Мы попробуем повторить успех Amazon и написать систему для рекомендации книг. Для начала немного поговорим о рекомендательных системах в целом.
#
# ### РЕКОМЕНДАТЕЛЬНЫЕ СИСТЕМЫ НА ПРАКТИКЕ
#
# Задача построения и использования рекомендательных систем очень сильно отличается от задачи классификации и анализа данных, так как здесь всегда есть пользователь (User), для которого вы составляете список рекомендаций.
#
# В условиях продакшена первая проблема, с которой приходится сталкиваться — это **холодный старт (Cold Start)**. Что рекомендовать человеку, если он только что к вам пришёл? Не знаете? Всё верно, ведь универсального решения ещё никто не придумал. Давайте посмотрим, как решают данную проблему существующие сервисы рекомендаций.
#
# **Вариант 1.** Просто даём пользователю список самых популярных товаров. На первый взгляд, это отличный вариант, чтобы решить все свои проблемы, но нет. Этот подход показывает самые низкие результаты в долгосрочной перспективе.
#
# ![proj-rec-2-3.png](attachment:proj-rec-2-3.png)
#
# **Вариант 2.** Просим пользователя при регистрации выбрать несколько интересных книг из списка. Затем на основании выбора делаем рекомендации. Например, так работает Netflix, только с фильмами и сериалами.
#
# ![proj-rec-2-2.jpeg](attachment:proj-rec-2-2.jpeg)
#
# **Вариант 3.** Знаменитое Вместе с этим товаром покупают…, или _Content based filtering_.
#
# ![proj-rec-2-4.png](attachment:proj-rec-2-4.png)
#
# Я предлагаю использовать последний вариант, или Content based filtering. Это значит, что пользователь будет заходить на страницу книги, а мы будем показывать в блоке рекомендаций похожие книги.
#
# Мы разобрались, какой тип рекомендаций мы будем давать. Остался вопрос: как всё это будет работать?
#
# Вспомним основные подходы.
#
# ### ВАРИАНТЫ ИСПОЛЬЗОВАНИЯ РЕКОМЕНДАТЕЛЬНЫХ СИСТЕМ
#
# ✔ **Онлайн**. Обучаем модель, используем её предсказания на новых или старых пользователях.
#
# _Плюсы:_ Точность, возможность использования с новыми пользователями.
#
# _Минусы:_ Затраты на предсказание и обучение.
#
# ✔ **Офлайн**. Один раз обучаем модель и пользуемся результатами. Это значит, что мы обучим модель, сделаем векторизованные представления наших объектов, или эмбеддинги, и будем пользоваться ими дальше.
#
# _Плюсы:_ Нет затрат на предсказание во время работы (inference). Можно хранить все рекомендации в базе данных, останутся только затраты на обращение к ней.
#
# _Минусы:_ Не можем давать пользователям персонализированных рекомендаций.
#
# Мы будем использовать офлайн-модель: её проще обучить и использовать. Несмотря на это, создание такой модели поможет вам в будущем, так как все основные идеи уже будут вам знакомы.

# %% [markdown]
# ### 6. Обучим и протестируем модель
#
# → Итак, мы решили делать рекомендательную систему.
#
# Очень сложно сделать сразу большой рабочий продукт. Мы начнём работу с построения **MVP (Minimum Viable Product)** — минимальной жизнеспособной версии, которую мы сможем показать нашим руководителям или инвесторам.
#
# Для обучения модели мы будем использовать датасет goodbooks-10k (https://github.com/zygmuntz/goodbooks-10k). Он содержит 6 миллионов рейтингов для 10 тысяч самых популярных книг.
#
# Также мы будем использовать библиотеку LightFM (https://making.lyst.com/lightfm/docs/home.html) для самого процесса обучения.

# %% [markdown]
# В скринкасте используется этот ноутбук (https://colab.research.google.com/drive/1xXLI_ZxIb6g8AR_kgTqCEqNSZfoUGFCx). Если вы хотите загрузить готовый рабочий ноутбук на своё устройство или свой Google Диск, вам понадобится папка с дополнительными файлами. Её можно найти здесь (https://drive.google.com/drive/folders/1lxo4bg-ywyuS-8zq9ldZDFKpSS3bBOuE).
#
# ### УСТАНОВИМ БИБЛИОТЕКИ И ПРОЧИТАЕМ ДАННЫЕ
#
# Установим библиотеку LightFM через команду:

# %%
pip install lightfm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import scipy.sparse as sparse
from lightfm import LightFM
from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import precision_at_k, recall_at_k
 
ratings = pd.read_csv('data/ratings.csv')
books = pd.read_csv('data/books.csv')
tags = pd.read_csv('data/tags.csv')
book_tags = pd.read_csv('data/book_tags.csv')

# %% [markdown]
# Если мы откроем файл с тегами tags.csv, то увидим, что там очень много неинформативных тегов:
#
# ![proj-rec-3-3.png](attachment:proj-rec-3-3.png)
#
# В нашем случае теги очень сильно влияют на качество модели. Что я сделал:
#
# Оставил около 500 наиболее популярных тегов.
# Вручную сгруппировал оставшиеся теги.
# Что получилось:
#
# ![proj-rec-3-4.png](attachment:proj-rec-3-4.png)
#
# Готовый файл доступен по ссылке:
#
# https://github.com/luhakv/cv_ml_nlp/blob/master/data/tags_cleaned-2.csv

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# ...

# %% [markdown]
# Вернёмся к датафрейму books. В нём у каждой книги есть два идентификатора: book_id и goodreads_book_id.
#
# ![proj-rec-3-5.png](attachment:proj-rec-3-5.png)
#
# Если мы посмотрим на датафрейм tags и на датафрейм books, то заметим, что у нас есть goodreads_book_id — от сервиса goodreads и просто book_id — который привязан к нашей таблице. Создадим словарь, с помощью которого по goodreads_book_id мы сможем находить book_id книги.

# %%
mapper = dict(zip(books.goodreads_book_id,books.book_id))

# %% [markdown]
# Теперь применим этот словарь, чтобы добавить id книги в dataframe book_tags.

# %%
tags = pd.read_csv('data/tags_cleaned.csv')
book_tags = book_tags[book_tags.tag_id.isin(tags.tag_id)]
book_tags['id'] = book_tags.goodreads_book_id.apply(lambda x: mapper[x])

# %% [markdown]
# Чтобы работать с моделями в библиотеке LightFM, нам нужно создать разрежённые матрицы. Мы будем хранить данные в формате COO (координатный формат представления данных). Вместо хранения всех значений, которые включают нулевые значения, мы будем хранить только ненулевые значения. В COO данные представлены в виде (строка, столбец, значение).

# %%
ratings_coo = sparse.coo_matrix((ratings.rating,(ratings.user_id,ratings.book_id)))
feature_ratings  = sparse.coo_matrix(([1]*len(book_tags),(book_tags.id,book_tags.tag_id)))

# %% [markdown]
# ### ОБУЧИМ МОДЕЛЬ
#
# Далее объявляем вспомогательные константы для обучения модели.

# %%
#число потоков нашего процессора. Зависит от того, на какой машине запускаете
NUM_THREADS = 8 

#число параметров вектора 
NUM_COMPONENTS = 60 

#число эпох обучения
NUM_EPOCHS = 10

# %% [markdown]
# На этапе создания модели мы используем библиотеку LightFM, чтобы сделать матричное разложение (ALS) наших рейтингов книг и получить два набора векторов, которые будут находиться внутри модели.

# %%
#Создаём модель
model = LightFM(learning_rate=0.05, loss='warp', no_components=NUM_COMPONENTS)
 
#Разбиваем наш датасет на обучающую и тестовую выборки
train,test = random_train_test_split(ratings_coo, test_percentage=0.2, random_state=None)

#Обучаем модель
model = model.fit(train, epochs=NUM_EPOCHS, num_threads=NUM_THREADS,item_features =feature_ratings)

# %% [markdown]
# ⭐ Синтаксис очень похож на привычный scikit-learn. Первый набор отвечает векторному представлению пользователя, а второй набор соответствует векторному представлению книг. Эти векторы мы будем использовать в следующей части.
#
# ### ТЕСТИРОВАНИЕ
#
# Перед тем как переходить к использованию модели, давайте посмотрим, насколько хорошо она обучилась.
#
# Мы будем использовать наиболее популярные (в рекомендательных системах) метрики качества **precision at k** и **recall at k**.
#
# ### PRECISION AT K
#
# Это отношение количества релевантных предложений в списке рекомендаций к общему количеству предложений, при этом количество предложений равно k.
#
# Что это значит? Допустим, мы делаем 10 рекомендаций и наша метрика precision at 10 равняется 80 %. Это значит, что 80 % наших рекомендаций релевантны для пользователя.
#
# ### RECALL AT K
#
# Это отношение количества релевантных предложений в списке рекомендаций к количеству релевантных предложений в принципе.
#
# Что это значит? Допустим, мы делаем 10 рекомендаций и наша метрика recall at 10 равняется 40 %. Это значит, что если взять все релевантные предложения, то 40 % из них появятся в списке наших рекомендаций.
#
# В идеальном варианте мы должны стремиться к precision и recall = 1.0. К сожалению, такое почти невозможно — как почти невозможно получить 100 %-ную точность в задачах классификации.
#
# Важный момент! Плохой precision или плохой recall не означает, что вы получите плохие эмбеддинги. Это следствие того, что модель тренируется через алгоритм ALS, который использует другую метрику качества при обучении.

# %%
#Тестируем нашу модель
precision_score = precision_at_k(
                     model,
                     test,
                     num_threads=NUM_THREADS,
                     k=10,
                     item_features=feature_ratings).mean()
 
recall_at_k = recall_at_k(model,
                     test,
                     num_threads=NUM_THREADS,
                     k=10,
                     item_features=feature_ratings).mean()

print(recall_at_k,precision_score)
# Out:
# 0.040385678416498705 0.087162845

# %% [markdown]
# Мои результаты:
#
# precision 8-10%
# recall 10-20%
#
# ⭐ Не самые идеальные результаты, но для тестирования функциональности такого baseline будет достаточно. Вы можете поиграть с параметрами, чтобы добиться иных результатов.
#
# ### Задание 6.1
# А какие значения получились у вас?
#
# precision at 10 - 40%
#
# recall at 10 - 87%

# %% [markdown]
# ### 7. Добавим эмбеддинги
# Воспользуемся обученной моделью, чтобы получить новые векторные представления книг, которые называются **эмбеддингами**. Вы уже встречались с этим понятием ранее, в модуле про NLP: простыми словами, мы представим каждую книгу большим количеством чисел. В нашем случае одной книге соответствует NUM_COMPONENTS = 60 (мы задавали это значение ранее).

# %%
# Достаём эбмеддинги

item_biases, item_embeddings = model.get_item_representations(features=feature_ratings)

# %% [markdown]
# Мы получили эмбеддинги — что делать с ними дальше? Эмбеддинги нам нужны, чтобы давать предсказание к каждой книге, а точнее искать наиболее похожие. Но как быстро найти среди 10 000 книг наиболее похожую? На помощь нам приходит **метод ближайших соседей**, approximate k-nn, который реализован в библиотеке nmslib (https://github.com/nmslib/nmslib).
#
# Вместо того чтобы перебирать все вершины, мы можем очень быстро обходить граф.
#
# ![proj-rec-3-1.png](attachment:proj-rec-3-1.png)

# %%
pip install nmslib
# Out:
# ...
#      |████████████████████████████████| 13.4 MB 2.0 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nmslib
 
#Создаём наш граф для поиска
nms_idx = nmslib.init(method='hnsw', space='cosinesimil')
 
#Начинаем добавлять наши книги в граф
nms_idx.addDataPointBatch(item_embeddings)
nms_idx.createIndex(print_progress=True)

# %% [markdown]
# Далее давайте напишем вспомогательную функцию, чтобы осуществлять поиск с помощью nmslib.

# %%
#Вспомогательная функция для поиска по графу
def nearest_books_nms(book_id, index, n=10):
    nn = index.knnQuery(item_embeddings[book_id], k=n)
    return nn

# %% [markdown]
# ### ПОСМОТРИМ НА РЕКОМЕНДАЦИИ НАШЕЙ МОДЕЛИ
#
# Давайте попробуем написать рекомендации к какой-нибудь книге, например к роману «1984» Джорджа Оруэлла.

# %%
books[books.original_title.str.find('1984')>=0].head(2)
# Out:
#      book_id  goodreads_book_id  best_book_id  work_id  books_count  \
# 845      846               5472          5472  2966408           51
#
#           isbn        isbn13                              authors  \
# 845  151010269  9.780151e+12  George Orwell, Christopher Hitchens
#
#      original_publication_year       original_title  ... ratings_count  \
# 845                     1950.0   Animal Farm & 1984  ...        116197
#
#     work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 845             118761                     1293       1212       3276
#
#      ratings_3  ratings_4  ratings_5  \
# 845      16511      40583      57179
#
#                                              image_url  \
# 845  https://images.gr-assets.com/books/1327959366m...
#
#                                        small_image_url
# 845  https://images.gr-assets.com/books/1327959366s...
#
# [1 rows x 23 columns]

# %% [markdown]
# Видим, что у книги id — 846.
#
# Ищем похожие книги.

# %%
nbm = nearest_books_nms(846,nms_idx)[0]

# %% [markdown]
# Выводим похожие книги.

# %%
books[books.book_id.isin(nbm)]
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 12         13               5470          5470    153313          995
# 13         14               7613          7613   2207778          896
# 47         48               4381          4381   1272463          507
# 54         55               5129          5129   3204877          515
# 172       173             227463        227463     23596          283
# 270       271              18373         18373   3337594          163
# 808       809               5479          5479  39947767           38
# 845       846               5472          5472   2966408           51
# 5871     5872            9748274       9748274  14637456           33
# 8139     8140               5481          5481  16335101           80
#
#            isbn        isbn13                                  authors  \
# 12    451524934  9.780452e+12  George Orwell, Erich Fromm, Celâl Üster
# ...

# %% [markdown]
# Посмотрим на результаты:
#
# ![dspr-ml-14.png](attachment:dspr-ml-14.png)

# %% [markdown]
# ️ Как мы можем увидеть, в результатах есть действительно похожие книги. За пару десятков строк кода мы написали свою рекомендательную систему. Отлично!
#
# ### Задание 7.1
# Найдите рекомендации для книги Thomas Harris, The Silence of the Lambs. Какие книги присутствуют в списке рекомендаций?
# Ответ: Shutter Island

# %%
books[books.original_title.str.find('The Silence of the Lambs')>=0].head(2)
# Out:
#      book_id  goodreads_book_id  best_book_id  work_id  books_count      isbn  \
# 208      209              23807         23807    22533          187  99446782
#
#            isbn13        authors  original_publication_year  \
# 208  9.780099e+12  Thomas Harris                     1988.0
#
#                original_title  ... ratings_count work_ratings_count  \
# 208  The Silence of the Lambs  ...        351107             366112
#
#      work_text_reviews_count  ratings_1  ratings_2  ratings_3  ratings_4  \
# 208                     3866      10268      12845      55427     123652
#
#      ratings_5                                          image_url  \
# 208     163920  https://images.gr-assets.com/books/1390426249m...
#
#                                        small_image_url
# 208  https://images.gr-assets.com/books/1390426249s...
#
# [1 rows x 23 columns]

# %%
nbm = nearest_books_nms(209,nms_idx)[0]
books[books.book_id.isin(nbm)]
# Out:
#       book_id  goodreads_book_id  best_book_id  work_id  books_count  \
# 208       209              23807         23807    22533          187
# 273       274              22034         22034   266624          259
# 430       431              28877         28877   925503          191
# 525       526              17231         17231  2113743           95
# 767       768              21686         21686  1234227          134
# 1175     1176              21671         21671  1234249           97
# 1484     1485              21704         21704      434           93
# 1801     1802              32418         32418  2992500          132
# 5312     5313              21727         21727   593515           46
# 9792     9793              15677         15677  1187279           77
#
#             isbn        isbn13                                  authors  \
# 208     99446782  9.780099e+12                            Thomas Harris
# ...

# %% [markdown]
# ### 8. Визуальный прототип
#
# → Теперь давайте превратим нашу модель в настоящий прототип.
#
# ### А ЗАЧЕМ НУЖЕН ПРОТОТИП?
#
# Представим ситуацию: вы собрали сложную модель и хотите показать результаты её работы заказчику, чтобы принять решение о внедрении модели в продакшен.
#
# Вы приходите на совещание, демонстрируете код на ноутбуке, даже скармливаете модели какие-то данные и… слышите в ответ тишину.
#
# Чаще всего ставить задачи команде дата-сайентистов будут специалисты из других отраслей (продуктовая команда, маркетинг и так далее). И чтобы суметь донести смысл своей работы, получить качественный фидбек и отследить возможные ошибки перед внедрением модели в продакшен, мы и строим прототипы.
#
# К счастью для нас, создавать наглядные и удобные для использования прототипы теперь можно и без знаний HTML, JavaScript, CSS и даже Flask! Хотя последнее, безусловно, пригодится вам на практике.
#
# ### ЧТО ТАКОЕ STREAMLIT?
#
# Мы будем делать прототип с помощью Streamlit (https://streamlit.io/) — это библиотека, которая позволяет быстро строить интерактивный интерфейс, пользуясь готовыми блоками (почти как Tilda для разработки сайтов). Большой плюс этого интерфейса в том, что впоследствии его можно загрузить на удалённый сервер. На примере сервиса книжных рекомендаций мы покажем, как сделать интерфейс с её помощью.
#
# ![rds-rec-1-2.png](attachment:rds-rec-1-2.png)
#
# ↑ Пример прототипа, написанного на Streamlit
#
# Весь следующий код мы будем писать уже не в ноутбуке, а в файле .py. Ниже вы можете найти все включённые в него блоки кода с комментариями.
#
# ### ПИШЕМ ОСНОВУ ДЛЯ ПРОТОТИПА
#
# Импортируем библиотеки для работы с данными.

# %% [markdown]
# Импортируем библиотеки для работы с данными.

# %%
import streamlit as st
import numpy as np
import pandas as pd
import lightfm as lf
import nmslib
import pickle
import scipy.sparse as sparse

# %% [markdown]
# Пропишем вспомогательные функции:

# %%
def nearest_books_nms(book_id, index, n=10):
    """Функция для поиска ближайших соседей, возвращает построенный индекс"""
    nn = index.knnQuery(item_embeddings[book_id], k=n)
    return nn

# %% [markdown]
# Первая функция использует наш построенный index для поиска книг. Думайте об этой функции как о реализации K-NN (k-ближайших соседей).
#
# Функция get_names просто возвращает список книг,  а точнее их названия, в виде [(Название книги, Имя Автора),...]:

# %%
def get_names(index):
    """
    input - idx of books
    Функция для возвращения имени книг
    return - list of names
    """
    names = []
    for idx in index:
        names.append('Book name:  {} '.format(
            name_mapper[idx]) + '  Book Author: {}'.format(author_mapper[idx]))
    return names

# %% [markdown]
# Чтение файлов никогда не было таким увлекательным!

# %%
def read_files(folder_name='data'):
    """
    Функция для чтения файлов + преобразование к  нижнему регистру
    """
    ratings = pd.read_csv(folder_name+'/ratings.csv')
    books = pd.read_csv(folder_name+'/books.csv')
    books['title'] = books.title.str.lower()
    return ratings, books

# %% [markdown]
# Снова создадим словари, чтобы получить возможность сопоставлять элементы из разных таблиц.

# %%
def make_mappers():
    """
    Функция для создания отображения id в title
    """
    name_mapper = dict(zip(books.id, books.title))
    author_mapper = dict(zip(books.id, books.authors))

    return name_mapper, author_mapper

# %% [markdown]
# Давайте загрузим векторные представления книг, которые мы сохранили в предыдущем модуле.

# %%
def load_embeddings():
    """
    Функция для загрузки векторных представлений
    """
    with open('item_embeddings.pickle', 'rb') as f:
        item_embeddings = pickle.load(f)

    # Тут мы используем nmslib, чтобы создать наш быстрый knn
    nms_idx = nmslib.init(method='hnsw', space='cosinesimil')
    nms_idx.addDataPointBatch(item_embeddings)
    nms_idx.createIndex(print_progress=True)
    return item_embeddings,nms_idx

# %% [markdown]
# А теперь выполним весь код, который мы написали.

# %%
#Загружаем данные
ratings, books  = read_files(folder_name='data') 
name_mapper, author_mapper = make_mappers()
item_embeddings,nms_idx = load_embeddings()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-50488b662032> in <module>
#       1 #Загружаем данные
#       2 ratings, books  = read_files(folder_name='data')
# ----> 3 name_mapper, author_mapper = make_mappers()
#       4 item_embeddings,nms_idx = load_embeddings()
#
# <ipython-input-28-3185b81452a3> in make_mappers()
#       3     Функция для создания отображения id в title
#       4     """
# ----> 5     name_mapper = dict(zip(books.id, books.title))
#       6     author_mapper = dict(zip(books.id, books.authors))
#       7
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
# ...

# %% [markdown]
# ### НАПОЛНЯЕМ НАШ ПРОТОТИП ВИЗУАЛЬНОЙ ЧАСТЬЮ
#
# Попросим пользователя ввести название книги.

# %%
#Форма для ввода текста
title = st.text_input('Book Name', '')
title = title.lower()
# Out:
# 2021-08-20 17:55:15.258
# ...
#   command:
#
#     streamlit run /home/dell/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py [ARGUMENTS]

# %% [markdown]
# Найдём в наших данных книгу, используя pandas.

# %%
#Наш поиск по книгам
output = books[books.title.str.contains(title) > 0]

# %% [markdown]
# Используем Streamlit, чтобы выбрать книгу из списка, и выводим её название.

# %%
#Выбор книги из списка
option = st.selectbox('Which book?', output['title'].values)

#Выводим книгу
'You selected: ', option
# Out:
# ('You selected: ', 'the hunger games (the hunger games, #1)')

# %% [markdown]
# Найдём рекомендации к книге с помощью функции nearest_books_nms.

# %%
#Ищем рекомендации
val_index = output[output['title'].values == option].id
index = nearest_books_nms(val_index, nms_idx, 5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-49bd391012f8> in <module>
#       1 #Ищем рекомендации
# ----> 2 val_index = output[output['title'].values == option].id
#       3 index = nearest_books_nms(val_index, nms_idx, 5)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'id'

# %% [markdown]
# И снова, пользуясь магией Streamlit, выводим книгу:

# %%
#Выводим рекомендации к ней
'Most similar books are: '
st.write('', get_names(index[0])[1:])

# %% [markdown]
# Осталось совсем немного!
#
# Теперь нужно в командной строке написать:

# %%
streamlit run app.py

# %% [markdown]
# После этого прототип будет запущен, и вы увидите что-то вроде:
#
# ![dspr-ml-16.png](attachment:dspr-ml-16.png)
#
# Получается, Streamlit запустил сервер на нашей локальной машине, и мы можем вводить название книг в нашу рекомендательную систему и получать ответ!
#
# ⭐️ Как видите, написать свою модель машинного обучения, а затем обернуть её в визуальный прототип действительно очень просто!

# %% [markdown]
# ### 9. Заключение
#
# → Подошёл к концу последний ознакомительный модуль блока Профориентация.
#
# В этом модуле вы:
#
# - познакомились с программой трека ML-инженер и узнали, какие результаты принесёт обучение этой специализации;
# - посмотрели глазами специалиста из сферы на работу и карьерный путь;
# - узнали, с какими кейсами может столкнуться ML-инженер, поняли особенности работы с бизнес-задачами;
# - а также написали собственную рекомендательную систему книг и создали виртуальный прототип.
#
# ⭐️ Надеемся, что у вас получилось составить впечатление о профессии. А впереди вас ждут выбор трека обучения, чек-поинт по вашей карьерной цели и финальный проект блока!
