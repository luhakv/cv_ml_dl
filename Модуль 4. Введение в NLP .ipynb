# %% [markdown]
# ## Юнит 9. Профориентация в Data Science
# ### Skillfactory: DSPR-19
# ### Модуль 4. Введение в NLP

# %% [markdown]
# ### 1. Введение
# → Вы посмотрели, чем занимаются специалисты по компьютерному зрению, а теперь пришло время познакомиться с другой профессией из сферы Deep Learning — NLP Engineer.
#
# И по традиции для начала давайте познакомимся с автором модуля:
#
# Привет всем!
#
# Меня зовут Черешнев Роман, я кандидат компьютерных наук, и сейчас я работаю в консалтинговой компании AISuperior на должности Senior Data Scientist. Я занимаюсь тем, что помогаю компаниям со всего мира решать их проблемы с помощью NLP и ML.
#
# Что вообще означает NLP? Не стоит путать NLP с другой, многим знакомой аббревиатурой НЛП (нейролингвистическое программирование).
#
# NLP расшифровывается как **Natural Language Processing (обработка естественного языка)**. Как понятно из названия, основная область работы NLP — это естественный человеческий язык. «Естественный» означает, что именно на этом языке мы с вами говорим и пишем без каких-либо ограничений.
#
# ⭐ Сформулируем суть работы NLP-инженера: обработка или получение полезной информации из обычного неструктурированного текста.
#
#
# Комментарий от автора
#
# У NLP есть интересная особенность. В компьютерном зрении неважно, где сфотографировали котика, в Африке или в России — он всегда остаётся котиком. Для NLP же часто приходится создавать решение под каждый язык, так как грамматика и слова на разных языках очень сильно отличаются, и часто решения, которые хорошо работают для одного языка, могут не заработать для другого, особенно если он из другой языковой семьи.
#
# ### ЧТО ВХОДИТ В АРСЕНАЛ NLP-ИНЖЕНЕРА?
#
# В качестве одного из основных инструментов естественно используется какой-то язык программирования, чаще всего это Python или R. В данном курсе мы будем сосредоточены только на Python, так как R больше используется в академических кругах.
#
# В качестве основной библиотеки Python для NLP чаще всего используется **NLTK (Natural Language Toolkit)**. Это, наверное, один из самых крупных модулей по работе с текстом, особенно с английским языком. Также есть **SpaCy**, который также имеет схожий арсенал по обработке текста. Эти библиотеки содержат в себе огромные возможности по обработке, трансформации и анализу текста. Другой популярный инструмент — это **Gensim**, он уже в себе содержит некоторые модели для перевода текста в векторное представление, о котором мы поговорим далее.
#
# _Источник (https://www.machinelearningmastery.ru/named-entity-recognition-3fad3f53c91e/)_
#
# И, конечно, не стоит забывать о библиотеках, которые создавались для русского языка. Это такие проекты, как **Natasha** и **DeepPavlov** из МФТИ.
#
# _Источник (https://deeppavlov.ai/)_
#
# И если раньше чаще применяли методы, основанные на каких-то эвристиках, то в последние 10-20 лет машинное обучение приобрело невероятную популярность в NLP. И поэтому в список инструментов NLP инженера входят также стандартные библиотеки и фреймворки машинного и глубокого обучения, например, scikit-learn, PyTorch, Tensorflow2/Keras и так далее.
#
# В этом модуле мы:
#
# - рассмотрим историю развития NLP, а также посмотрим на библиотеки, которые применяются для различных задач;
# - разберём, как можно решить задачи без машинного обучения стандартными средствами и эвристическими алгоритмами (что до сих пор довольно часто применяется) ;
# - посмотрим несколько способов получения векторов из естественного текста и слов, а также обсудим особый вид нейронных сетей под названием рекуррентные нейронные сети, который очень часто применяется в NLP и в работе с последовательностями;
# - конечно же, попробуем решить некоторые задачи этими методами, чтобы лучше понять, чем занимается NLP-инженер;
# - а в самом конце мы обсудим трансформеры. И нет, это не роботы, которые могут превращаться в машины. Это особая нейронная сеть, которая появилась сравнительно недавно и которая сейчас является, наверное, самым мощным инструментом для обработки естественного языка.
#
# Ну что, поехали? ⭐

# %% [markdown]
# ### 2. Классические задачи NLP
#
# → Для начала разберёмся с тем, какие задачи решает NLP-инженер.
#
# Вообще задачи в NLP можно разделить на две большие группы:
#
# - Работа  со звуком (когда мы работаем с записанной речью).
# - Работа с текстом.
#
# Но для работы со звуком мы просто можем перевести речь в текст методами Speech2Text и затем применить методы обработки текстов. И в курсе в основном мы будем касаться именно работы с текстом, а не со звуком, потому что существуют уже неплохие готовые решения по переводу речи в текст (например, именно так изначально было записано то, что вы сейчас читаете :))
#
# Что же касается бизнеса и NLP, тут дела обстоят очень даже хорошо. Считается, что цивилизация появляется, когда появляется письменность, и поэтому в цивилизованных компаниях уже давно принято вести документооборот на естественных языках. Также очень много текста логируется или записывается куда-то (например, тексты общения с оператором из клиентской поддержки), и оттуда можно достать много полезных данных.
#
# Вообще практика вести документооборот очень старая, и поэтому у компании всегда есть какие-то накопленные документы и тексты, которые часто требуется обработать. Так что работа для NLP-инженера найдётся всегда.
#
# Итак, давайте более конкретно поговорим о задачах, которые решает NLP-инженер.
#
# ### КЛАССИФИКАЦИЯ
#
# Одна из самых популярных задач — это задача классификации текста. У нас есть набор документов, и каждый документ должен быть отнесён к одному из N заранее определённых классов. Хорошо знакомый вам пример — это спам-фильтр, который должен определить, является сообщение спамом или нет. Другой классический пример — это сентимент-анализ, или анализ тональности текста.  Например, у нас есть рецензии от КиноПоиска, и мы хотим понять по тексту, является эта рецензия позитивной, негативной или нейтральной.
#
# ### КЛАССИФИКАЦИЯ ТОКЕНОВ
#
# Но кроме задачи классификации всего текста, иногда требуется выполнить задачу классификации токена.
#
# Токен — это то, из чего состоят предложения (в русском и английском языке токены — это просто слова).
#
# Например, задача «Определение частей речи в предложении» является задачей классификации токенов.

# %% [markdown]
# ![dspr_md4_2_1.png](attachment:dspr_md4_2_1.png)

# %% [markdown]
# ### NAMED-ENTITY RECOGNITION
#
# Другая интересная задача — это Named-entity Recognition, или NER. В этой задаче мы пытаемся понять, является слово какой-то сущностью или нет.
#
# Под сущностью может подразумеваться много чего. Чаще всего это персоны, географические объекты, названия каких-то учреждений или, например, даты, времена и валюты.
#
# ![dspr_md4_2_2.png](attachment:dspr_md4_2_2.png)
#
# _Источник (https://www.machinelearningmastery.ru/named-entity-recognition-ner-meeting-industrys-requirement-by-applying-state-of-the-art-deep-698d2b3b4ede/)_

# %% [markdown]
# ### Задание 2.1
# Чем отличается задача классификации текста от задачи классификации токенов?
#
# Ответ: При классификации текста мы хотим найти один класс для всего текста, а при классификации токенов — класс для каждого токена. верно

# %% [markdown]
# ### ПОИСК
#
# Другой крупный класс задач — это задачи, связанные с поиском и ранжированием.
#
# Вероятно, все из нас на постоянной основе используют такие поисковики, как Яндекс или Google. В данном случае задача состоит в том, чтобы по запросу найти наиболее релевантные документы или, в случае Яндекса или Google, сайты, которые соответствуют этому запросу.
#
# ![dspr_md4_2_3.png](attachment:dspr_md4_2_3.png)
#
# ### СРАВНЕНИЕ ТЕКСТОВ
#
# Также есть задача сравнения двух текстов. Например, для решения одной бизнес-задачи мне нужно было сопоставить названия товаров из двух разных баз данных двух различных магазинов. К примеру, в одном магазине товар назывался iPhone 10 XS Gold, а в другом магазине он назывался iPhone 10 золотой.
#
# ### ПОИСК ДУБЛИКАТОВ
#
# Также существует задача поиска неполных дубликатов. Мне приходилось решать задачу, когда очень много сотрудников скидывали документы в файловые хранилища, и очень часто один и тот же документ лежал в разных местах. Проблема была в том, что появлялись разные версии документов, и наступала неразбериха. Задача была в том, чтобы во время того как закидывается документ, найти его копию или уже изменённую версию и предупредить об этом сотрудника.
#
# ### ЧАТ-БОТЫ И ДИАЛОГОВЫЕ СИСТЕМЫ
#
# Ну и, конечно же, не стоит забывать об очень бурно развивающейся области чат-ботов и диалоговых систем, а также персональных помощников. Сейчас почти любая компания среднего размера пытается сделать собственного чат-бота для работы с клиентом или каких-то своих внутренних нужд: например, чтобы уменьшить нагрузку на операторов или автоматизировать процессы.
#
# При этом сами чат-боты внутри могут быть совершенно разными. Они могут как просто реагировать на какие-то ключевые слова, могут работать на основании классификации намерений и специальных правил, которые говорят, что именно нужно ответить на конкретное сообщение, или же они могут самостоятельно генерировать ответ на совершенно любой вопрос.

# %% [markdown]
# ### Задание 2.2
#
# Определите, к какой группе задач относится конкретная задача.
#
# Ответ:
# - Классификация - Определение тематики новости (темы известны заранее)
# - Классификация токенов - Определение в тексте слов, которые придают ему негативную окраску
# - Поиск - Автоматическое определение адреса из списка адресов в сообщении
