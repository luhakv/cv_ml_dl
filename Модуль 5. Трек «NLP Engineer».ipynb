# %% [markdown]
# ## Юнит 9. Профориентация в Data Science
# ### Skillfactory: DSPR-19
# ### Модуль 5. Трек «NLP Engineer»

# %% [markdown]
# ### 1. Введение
# → В предыдущем модуле вы познакомились с основными задачами NLP-специалиста, узнали историю развития технологий и инструментов в области обработки естественного языка, а также попрактиковались в использовании некоторых из них. Теперь давайте узнаем, что ждёт вас дальше, если вы примете решение обучаться на треке «NLP Engineer».
#
# В этом модуле вы:
#
# - узнаете, из каких тем состоит образовательная программа трека и какие результаты вы получите после её освоения;
# - познакомитесь со специалистом из сферы NLP, от первого лица узнаете об особенностях его работы и тонкостях выбора направления в Data Science;
# - разберёте два реальных кейса из области обработки текстов, узнаете, с какими сложностями может столкнуться NLP-специалист;
# - а также познакомитесь с интересным проектом из области NLP и разберётесь, как самостоятельно генерировать тексты любого формата.
#
# ⭐️ Не забывайте уделять время рефлексии и оценке собственных ощущений. Нравится ли вам то, что вы узнали? Хотели ли бы вы заниматься этим? Представляете ли вы себя на месте специалиста-спикера?

# %% [markdown]
# ### 2. О треке «NLP Engineer»
# → Для начала, конечно же, стоит познакомиться с программой. Так же, как и в программе трека по компьютерному зрению, выделенные тематические блоки не равны по объёму и длительности, а основной фокус трека направлен на практическое применение знаний — таким материалам отведена наибольшая часть времени обучения.
#
# Итак, вот что вас ждёт на треке NLP Engineer:
#
# https://view.genial.ly/609b85f8db28e00da4d84d6b/interactive-content-dsprprogramma-treka-nlp-engineer

# %% [markdown]
# ### 3. Глазами специалиста
# → Настало время познакомиться со специалистом по NLP, который поделится с вами своим опытом работы в этой области.
#
#
# Знакомьтесь! Мурат Апишев, не только эксперт по анализу данных и обработке естественного языка, но и один из основателей стартапа в сфере NLP.
#
# ⚡ Осторожно! Возможны инсайты :)
#
# А теперь давайте немного порефлексируем. Не торопитесь отвечать на вопросы, постарайтесь как можно более ясно представить себя в описанных ситуациях и понять, подходит ли вам тот или иной вариант.
#
# Верных и неверных ответов нет — это опрос.

# %% [markdown]
# ### 4. Кейс из опыта NLP-инженера
# → Продолжаем погружаться в реальный NLP! На очереди — даже не один, а два реальных кейса из практики Мурата Апишева. Как строится работа над NLP-задачей? Какие проблемы могут возникать уже после того, как модель запущена в продакшен? Что важно обязательно помнить и учитывать? Давайте посмотрим.

# %% [markdown]
# ### Задание 4.2
# К какому способу разметки текстовых данных чаще всего приходится прибегать в решении реальных задач?
#
# Ответ: Все - Разметка своими руками, Использование словарей/правил/регулярных выражений, Экспертная разметка, Разметка с помощью краудсорсинга
