# %% [markdown]
# ## Юнит 9. Профориентация в Data Science
# ### Skillfactory: DSPR-19
# ### Модуль 7. Трек «ML-инженер»

# %% [markdown]
# 1. О чём этот модуль?
#
# В предыдущем модуле вы познакомились со спецификой профессии ML-инженера. Пришло время внимательнее посмотреть на соответствующий трек второго года обучения, познакомиться со специалистом из сферы и прикоснуться к одной из интересных задач, с которой вы можете столкнуться в роли ML-инженера.
#
# ### ЧТО ВЫ УЗНАЕТЕ В ЭТОМ МОДУЛЕ?
#
# - узнаете, из каких тем состоит образовательная программа трека и какие результаты вы получите после их прохождения;
# - от опытного ML-инженера вы узнаете об особенностях его пути и получите советы по выбору направления в Data Science;
# - узнаете, с какими кейсами вы можете столкнуться в роли ML-инженера на примере опыта специалиста из сферы;
# - а также познакомитесь с рекомендательными системами и попробуете создать одну из них самостоятельно!
#
# ⭐️ Не забывайте уделять время рефлексии и оценке собственных ощущений. Нравится ли вам то, что вы узнали? Хотели бы вы заниматься этим? Представляете ли вы себя на месте специалиста-спикера?

# %% [markdown]
# → Программа трека ML-инженер отличается более глубоким погружением в уже изученные вами темы. Также вы разберёте бизнес-задачи и инженерные инструменты. Как и два других, этот трек фокусируется на практическом применении знаний и инструментов.
#
# ️Давайте посмотрим, что вас ждёт на треке ML-инженер!
#
# https://view.genial.ly/609bc328d22b940dcff6665a/interactive-content-dsprprogramma-treka-ml-engineer

# %% [markdown]
# ### 3. Глазами специалиста
#
# → Настало время познакомиться со специалистом в области ML.
#
# Знакомьтесь — Александр Кондрашкин. Сейчас он работает старшим аналитиком в КиноПоиске, и ему определённо есть о чём рассказать, начиная с должности разработчика и заканчивая собственным стартапом в области машинного обучения. Передаём ему слово!
#
# ⚡ Осторожно! Возможны инсайты :)

# %% [markdown]
# ### 4. Кейс из опыта ML-инженера
# → Как вы уже могли понять, ML-инжиниринг включает в себя довольно широкий спектр разнообразных задач, и потому специалист может столкнуться с большим количеством совершенно разных сложностей. Однако Александр Кондрашкин поделится с вами кейсами из практики и советами, которые будут важны для каждого будущего ML-инженера вне зависимости от специфики сферы.

# %% [markdown]
# ### Задание 4.1
# Как модель предсказания временных рядов может помочь взаимодействию с заказчиком в лице бизнеса? Выберите все верные варианты.
# Ответ:
# - A Через демонстрацию положительного влияния на метрику тех действий, которые были предприняты ранее
# - D Через использование её как альтернативы A/B-тестированию при невозможности его проведения
#
# ### Задание 4.2
# Как определить влияние использования модели на показатели прибыли в случае, если модель внедрена в один из семи сервисов, работающих по одной подписке?
# Ответ: Высчитывать соотношение прибыли по соотношению активности пользователя в сервисах

# %% [markdown]
# ### 5. Рекомендательные системы
#
# Привет! С вами снова Эмиль Магеррамов.
#
# Машинное обучение — сложная область. Но сложная не потому, что ей сложно обучиться, а потому, что во время обучения перед вами встаёт выбор: в какое из направлений пойти. Машинное обучение сейчас применяется в разных сферах: от финансов до нефтяной отрасли. При этом писать модели машинного обучения не так уж сложно, и мы сейчас в этом убедимся.
#
# Давайте напишем свою модель машинного обучения и сделаем её визуальный прототип!
#
# Для начала выберем, какую модель мы будем делать и для чего она нужна. Если вы много читаете, то знаете, как важны рекомендации. Особенно хорошо, если рекомендации основываются на том, что вам самим нравится.
#
# ✏️ Мы попробуем повторить успех Amazon и написать систему для рекомендации книг. Для начала немного поговорим о рекомендательных системах в целом.
#
# ### РЕКОМЕНДАТЕЛЬНЫЕ СИСТЕМЫ НА ПРАКТИКЕ
#
# Задача построения и использования рекомендательных систем очень сильно отличается от задачи классификации и анализа данных, так как здесь всегда есть пользователь (User), для которого вы составляете список рекомендаций.
#
# В условиях продакшена первая проблема, с которой приходится сталкиваться — это **холодный старт (Cold Start)**. Что рекомендовать человеку, если он только что к вам пришёл? Не знаете? Всё верно, ведь универсального решения ещё никто не придумал. Давайте посмотрим, как решают данную проблему существующие сервисы рекомендаций.
#
# **Вариант 1.** Просто даём пользователю список самых популярных товаров. На первый взгляд, это отличный вариант, чтобы решить все свои проблемы, но нет. Этот подход показывает самые низкие результаты в долгосрочной перспективе.
#
# ![proj-rec-2-3.png](attachment:proj-rec-2-3.png)
#
# **Вариант 2.** Просим пользователя при регистрации выбрать несколько интересных книг из списка. Затем на основании выбора делаем рекомендации. Например, так работает Netflix, только с фильмами и сериалами.
#
# ![proj-rec-2-2.jpeg](attachment:proj-rec-2-2.jpeg)
#
# **Вариант 3.** Знаменитое Вместе с этим товаром покупают…, или _Content based filtering_.
#
# ![proj-rec-2-4.png](attachment:proj-rec-2-4.png)
#
# Я предлагаю использовать последний вариант, или Content based filtering. Это значит, что пользователь будет заходить на страницу книги, а мы будем показывать в блоке рекомендаций похожие книги.
#
# Мы разобрались, какой тип рекомендаций мы будем давать. Остался вопрос: как всё это будет работать?
#
# Вспомним основные подходы.
#
# ### ВАРИАНТЫ ИСПОЛЬЗОВАНИЯ РЕКОМЕНДАТЕЛЬНЫХ СИСТЕМ
#
# ✔ **Онлайн**. Обучаем модель, используем её предсказания на новых или старых пользователях.
#
# _Плюсы:_ Точность, возможность использования с новыми пользователями.
#
# _Минусы:_ Затраты на предсказание и обучение.
#
# ✔ **Офлайн**. Один раз обучаем модель и пользуемся результатами. Это значит, что мы обучим модель, сделаем векторизованные представления наших объектов, или эмбеддинги, и будем пользоваться ими дальше.
#
# _Плюсы:_ Нет затрат на предсказание во время работы (inference). Можно хранить все рекомендации в базе данных, останутся только затраты на обращение к ней.
#
# _Минусы:_ Не можем давать пользователям персонализированных рекомендаций.
#
# Мы будем использовать офлайн-модель: её проще обучить и использовать. Несмотря на это, создание такой модели поможет вам в будущем, так как все основные идеи уже будут вам знакомы.

# %% [markdown]
# ### 6. Обучим и протестируем модель
#
# → Итак, мы решили делать рекомендательную систему.
#
# Очень сложно сделать сразу большой рабочий продукт. Мы начнём работу с построения **MVP (Minimum Viable Product)** — минимальной жизнеспособной версии, которую мы сможем показать нашим руководителям или инвесторам.
#
# Для обучения модели мы будем использовать датасет goodbooks-10k (https://github.com/zygmuntz/goodbooks-10k). Он содержит 6 миллионов рейтингов для 10 тысяч самых популярных книг.
#
# Также мы будем использовать библиотеку LightFM (https://making.lyst.com/lightfm/docs/home.html) для самого процесса обучения.

# %% [markdown]
# В скринкасте используется этот ноутбук (https://colab.research.google.com/drive/1xXLI_ZxIb6g8AR_kgTqCEqNSZfoUGFCx). Если вы хотите загрузить готовый рабочий ноутбук на своё устройство или свой Google Диск, вам понадобится папка с дополнительными файлами. Её можно найти здесь (https://drive.google.com/drive/folders/1lxo4bg-ywyuS-8zq9ldZDFKpSS3bBOuE).
#
# ### УСТАНОВИМ БИБЛИОТЕКИ И ПРОЧИТАЕМ ДАННЫЕ
#
# Установим библиотеку LightFM через команду:

# %%
pip install lightfm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import scipy.sparse as sparse
from lightfm import LightFM
from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import precision_at_k, recall_at_k
 
ratings = pd.read_csv('data/ratings.csv')
books = pd.read_csv('data/books.csv')
tags = pd.read_csv('data/tags.csv')
book_tags = pd.read_csv('data/book_tags.csv')

# %% [markdown]
# Если мы откроем файл с тегами tags.csv, то увидим, что там очень много неинформативных тегов:
#
# ![proj-rec-3-3.png](attachment:proj-rec-3-3.png)
#
# В нашем случае теги очень сильно влияют на качество модели. Что я сделал:
#
# Оставил около 500 наиболее популярных тегов.
# Вручную сгруппировал оставшиеся теги.
# Что получилось:
#
# ![proj-rec-3-4.png](attachment:proj-rec-3-4.png)
#
# Готовый файл доступен по ссылке:

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# ...
